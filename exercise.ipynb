# %% [markdown]
# <a href="https://colab.research.google.com/github/bgorume/greends-fads-first-project/blob/main/exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("vikasukani/forest-firearea-datasets")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 7.10k/7.10k [00:00<00:00, 9.62MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/vikasukani/forest-firearea-datasets/versions/1

# %%
import pandas as pd

# %%
import os

# %%
file_path=os.path.join(path,"forestfires.csv")
df=pd.read_csv(file_path)
display(df)
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
print(df)
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
df.columns.to_list()
# Out:
# ['X',
#  'Y',
#  'month',
#  'day',
#  'FFMC',
#  'DMC',
#  'DC',
#  'ISI',
#  'temp',
#  'RH',
#  'wind',
#  'rain',
#  'area']

# %%
df['temp']
# Out:
# 0       8.2
# 1      18.0
# 2      14.6
# 3       8.3
# 4      11.4
#        ...
# 512    27.8
# 513    21.9
# 514    21.2
# 515    25.6
# 516    11.8
# Name: temp, Length: 517, dtype: float64

# %%
# Filter for fires where the temperature is higher than 25
fires_temp_above_25 = df[df['temp'] > 25]
display(fires_temp_above_25)
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 14   6  5   sep  wed  92.9  133.3  699.6   9.2  26.4  21   4.5   0.0  0.00
# 28   6  3   sep  sat  93.4  145.4  721.4   8.1  30.2  24   2.7   0.0  0.00
# 30   6  3   sep  fri  94.3   85.1  692.3  15.9  25.4  24   3.6   0.0  0.00
# 45   5  6   sep  wed  94.3   85.1  692.3  15.9  25.9  24   4.0   0.0  0.00
# 55   4  3   sep  thu  92.9  137.0  706.4   9.2  27.7  24   2.2   0.0  0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...   ...
# 507  2  4   aug  fri  91.0  166.9  752.6   7.1  25.9  41   3.6   0.0  0.00
# 508  1  2   aug  fri  91.0  166.9  752.6   7.1  25.9  41   3.6   0.0  0.00
# 511  8  6   aug  sun  81.6   56.7  665.6   1.9  27.8  35   2.7   0.0  0.00
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0  6.44
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0  0.00
#
# [65 rows x 13 columns]

# %%
# Filter for fires where the temperature is higher than 25 and between 20 and 30 (inclusive of 30)
fires_temp_25_to_30 = df[(df['temp'] > 25) & (df['temp'] <= 30)]
display(fires_temp_25_to_30)
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain     area
# 14   6  5   sep  wed  92.9  133.3  699.6   9.2  26.4  21   4.5   0.0     0.00
# 30   6  3   sep  fri  94.3   85.1  692.3  15.9  25.4  24   3.6   0.0     0.00
# 45   5  6   sep  wed  94.3   85.1  692.3  15.9  25.9  24   4.0   0.0     0.00
# 55   4  3   sep  thu  92.9  137.0  706.4   9.2  27.7  24   2.2   0.0     0.00
# 74   5  4   sep  fri  93.3  141.2  713.9  13.9  27.6  30   1.3   0.0     0.00
# 86   1  2   sep  thu  92.9  137.0  706.4   9.2  25.4  27   2.2   0.0     0.00
# 88   1  2   sep  sun  93.5  149.3  728.6   8.1  25.3  36   3.6   0.0     0.00
# 145  6  5   aug  thu  95.2  131.7  578.8  10.4  27.4  22   4.0   0.0     0.90
# 154  1  5   sep  sat  93.4  145.4  721.4   8.1  29.6  27   2.7   0.0     1.46
# 156  2  4   sep  sat  93.4  145.4  721.4   8.1  28.6  27   2.2   0.0     1.61
# 228  4  6   sep  sun  93.5  149.3  728.6   8.1  28.3  26   3.1   0.0    64.10
# ...

# %%
df['month']
# Out:
# 0      mar
# 1      oct
# 2      oct
# 3      mar
# 4      mar
#       ...
# 512    aug
# 513    aug
# 514    aug
# 515    aug
# 516    nov
# Name: month, Length: 517, dtype: object

# %%
import pandas as pd

# Assuming 'months' list already exists from previous execution
# If not, it can be defined as:
months = [
    'January', 'February', 'March', 'April', 'May', 'June',
    'July', 'August', 'September', 'October', 'November', 'December'
]

# Create the 'mth' column with 3-letter lowercase abbreviations
mth_abbreviations = [month[:3].lower() for month in months]

# Create the new DataFrame
month_df = pd.DataFrame({
    'mth': mth_abbreviations,
    'Month': months
})

display(month_df)
# Out:
#     mth      Month
# 0   jan    January
# 1   feb   February
# 2   mar      March
# 3   apr      April
# 4   may        May
# 5   jun       June
# 6   jul       July
# 7   aug     August
# 8   sep  September
# 9   oct    October
# 10  nov   November
# 11  dec   December

# %%
merged_df = pd.merge(df, month_df, left_on='month', right_on='mth', how='left')
merged_df.drop(columns='mth', inplace=True)
display(merged_df)
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area  \
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
#         Month
# 0       March
# 1     October
# ...

# %%
firesbymonth = monthly_summary
display(firesbymonth)
# Out:
#         Month   avg_temp     avg_RH  fire_count
# 0       April  12.044444  46.888889           9
# 1      August  21.631522  45.489130         184
# 2    December   4.522222  38.444444           9
# 3    February   9.635000  55.700000          20
# 4     January   5.250000  89.000000           2
# 5        July  22.109375  45.125000          32
# 6        June  20.494118  45.117647          17
# 7       March  13.083333  40.000000          54
# 8         May  14.650000  67.000000           2
# 9    November  11.800000  31.000000           1
# 10    October  17.093333  37.466667          15
# 11  September  19.612209  42.843023         172
